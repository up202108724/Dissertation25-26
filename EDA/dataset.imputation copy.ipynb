# %%
import pandas as pd

# %%
df = pd.read_feather('../dataset/data_andre.feather')
df['date'] = pd.to_datetime(df['date'])

# %%
min_date = df['date'].min()
max_date = df['date'].max()
expected_dates = pd.date_range(start=min_date, end=max_date, freq='D')
expected_count = len(expected_dates)

print(f"Global date range: {min_date.date()} to {max_date.date()} ({expected_count} days)")
# Out:
# Global date range: 2021-01-23 to 2023-02-22 (761 days)

# %%
# Products that start selling AFTER the global min_date
first_sale = (
    df.groupby(['item_id', 'store_id'])['date']
    .min()
    .reset_index()
    .rename(columns={'date': 'first_sale_date'})
)

late_starters = first_sale[first_sale['first_sale_date'] > min_date].copy()
late_starters['days_late'] = (late_starters['first_sale_date'] - min_date).dt.days
late_starters = late_starters.sort_values('days_late', ascending=False).reset_index(drop=True)

print(f"Products starting after min_date ({min_date.date()}): {len(late_starters)} / {len(first_sale)}")
print(f"\nDays late distribution:")
print(late_starters['days_late'].describe().round(1))
print()
late_starters
# Out:
# Products starting after min_date (2021-01-23): 165 / 1427
#
# Days late distribution:
# count    165.0
# mean       6.5
# std       14.2
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        4.0
# max       89.0
# Name: days_late, dtype: float64
#      item_id  store_id first_sale_date  days_late
# 0      70069      6269      2021-04-22         89
# 1     552377      6269      2021-04-03         70
# 2     526768      6269      2021-04-03         70
# 3     540575      6269      2021-04-03         70
# 4      65691      6269      2021-03-23         59
# ..       ...       ...             ...        ...
# 160    47141      6269      2021-01-24          1
# 161   144855      6269      2021-01-24          1
# 162    47142      6269      2021-01-24          1
# 163   132687      6269      2021-01-24          1
# 164   136901      6269      2021-01-24          1
#
# [165 rows x 4 columns]

# %%
import numpy as np

ADI_THRESHOLD = 1.32
CV_THRESHOLD  = 0.49

rows = []
for _, row in late_starters.iterrows():
    item_id, store_id = row['item_id'], row['store_id']
    y = df[(df['item_id'] == item_id) & (df['store_id'] == store_id)]['value'].to_numpy()

    non_zero = int((y > 0).sum())
    adi = np.inf if non_zero == 0 else len(y) / non_zero

    nz_vals = y[y > 0]
    if len(nz_vals) > 1:
        cv = float(np.std(nz_vals, ddof=1) / np.mean(nz_vals))
    elif len(nz_vals) == 1:
        cv = 0.0
    else:
        cv = np.inf

    if adi <= ADI_THRESHOLD and cv <= CV_THRESHOLD:
        label = "smooth"
    elif adi <= ADI_THRESHOLD and cv > CV_THRESHOLD:
        label = "erratic"
    elif adi > ADI_THRESHOLD and cv <= CV_THRESHOLD:
        label = "intermittent"
    else:
        label = "lumpy"

    rows.append({'item_id': item_id, 'store_id': store_id, 'adi_cv_label': label, 'adi': round(adi, 4), 'cv': round(cv, 4)})

late_starters_classified = late_starters.merge(pd.DataFrame(rows), on=['item_id', 'store_id'], how='left')
print(late_starters_classified['adi_cv_label'].value_counts())
late_starters_classified

# %%
date_counts = df.groupby(['item_id', 'store_id'])['date'].nunique().reset_index()
date_counts.rename(columns={'date': 'actual_days'}, inplace=True)
incomplete_products = date_counts[date_counts['actual_days'] < expected_count]

print(f"\nTotal product-store combinations: {len(date_counts)}")
print(f"Total incomplete combinations: {len(incomplete_products)}")

if len(incomplete_products) > 0:
    print("\nSample of incomplete products:")
incomplete_products.head(10)
# Out:
# Total product-store combinations: 1427
# Total incomplete combinations: 467
#
# Sample of incomplete products:
#     item_id  store_id  actual_days
# 6       176      6269          760
# 14      260      6269          759
# 28      471      6269          739
# 31      493      6269          759
# 34      514      6269          751
# 37      612      6269          760
# 41      676      6269          760
# 48      779      6269          734
# 50      808      6269          760
# 65     1241      6269          759

# %%
unique_items = df[['item_id', 'store_id']].drop_duplicates()
dates_df = pd.DataFrame({'date': expected_dates})
full_grid = unique_items.merge(dates_df, how='cross')
df_fulfilled = full_grid.merge(df, on=['item_id', 'store_id', 'date'], how='left')

# %%
df_fulfilled['value'] = df_fulfilled['value'].fillna(0)

# %%
promo_cols = [c for c in df_fulfilled.columns if c.startswith('promo_type_') or c.startswith('promo_value_')]
df_fulfilled[promo_cols] = df_fulfilled[promo_cols].fillna(0)

# %%
cat_cols = [c for c in df_fulfilled.columns if c in ('cat_label', 'sdep_label', 'dep_label', 'dmn_label')
or c.startswith('cat_label_') or c.startswith('sdep_label_')
or c.startswith('dep_label_') or c.startswith('dmn_label_')]
if cat_cols:
    df_fulfilled[cat_cols] = (
    df_fulfilled.groupby(['item_id', 'store_id'])[cat_cols]
    .transform(lambda s: s.ffill().bfill())
    )

print(f"\nOriginal row count: {len(df)}")
print(f"Fulfilled row count: {len(df_fulfilled)}")
# Out:
# Original row count: 1082371
# Fulfilled row count: 1085947

# %%
remaining_nans = df_fulfilled.isnull().sum()
remaining_nans = remaining_nans[remaining_nans > 0]
if len(remaining_nans):
    print(f"\nRemaining NaNs after imputation:\n{remaining_nans}")
else:
    print("\nNo remaining NaNs.")

df_fulfilled.to_feather('../dataset/data_andre_fulfilled.feather')
# Out:
# No remaining NaNs.
