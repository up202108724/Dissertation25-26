# %%
from dataclasses import dataclass
from typing import Tuple, Optional

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import sys
import os

# Add the parent directory to sys.path to allow importing model_utils
current_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.dirname(current_dir)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# Alternative if running interactively and __file__ is not defined:
# sys.path.append(os.path.abspath('..'))
sys.path.append('..')

# %%
def make_windows(
    series: np.ndarray,
    lookback: int,
    horizon: int,
) -> Tuple[np.ndarray, np.ndarray]:

    series = np.asarray(series, dtype=np.float32)
    if series.ndim == 1:
        series = series[:, None]  # (T, 1)

    T, C = series.shape
    N = T - lookback - horizon + 1
    if N <= 0:
        raise ValueError("Time series too short for given lookback/horizon.")

    X = np.zeros((N, lookback, C), dtype=np.float32)
    y = np.zeros((N, horizon, C), dtype=np.float32)

    for i in range(N):
        X[i] = series[i : i + lookback]
        y[i] = series[i + lookback : i + lookback + horizon]

    return X, y

# %%
class WindowDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray):
        self.X = torch.from_numpy(X)  # (N, L, C)
        self.y = torch.from_numpy(y)  # (N, H, C)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
class MLPForecaster(nn.Module):
    def __init__(
        self,
        lookback: int,
        in_channels: int,
        horizon: int,
        out_dim: int = 1,                 # often 1 for a single target variable
        hidden_sizes=(64, 32),
        dropout: float = 0.2,
        activation: str = "relu",
    ):
        super().__init__()
        self.lookback = lookback
        self.in_channels = in_channels
        self.horizon = horizon
        self.out_dim = out_dim

        act = {"relu": nn.ReLU, "gelu": nn.GELU, "tanh": nn.Tanh}[activation]

        layers = []
        prev = lookback * in_channels
        for hs in hidden_sizes:
            layers += [nn.Linear(prev, hs), act(), nn.Dropout(dropout)]
            prev = hs
        layers += [nn.Linear(prev, horizon * out_dim)]

        self.net = nn.Sequential(*layers)

    def forward(self, x):
        # x: (B, L, C)
        b = x.size(0)
        x = x.reshape(b, -1)  # flatten - changed from .view to .reshape
        y = self.net(x)    # (B, H*out_dim)
        return y.view(b, self.horizon, self.out_dim)

# %%
# -----------------------------------------------------------------------------
# DATA LOADING & PREPROCESSING
# -----------------------------------------------------------------------------
DATA_PATH = '../dataset/subset_set.feather'  # Adjust path if needed
print(f"Loading data from {DATA_PATH}...")
# Use pd.read_feather instead of feather.read_table to get a DataFrame directly
df = pd.read_feather(DATA_PATH)

# Define constants
DATE_COL = 'date'
TARGET_COL = 'value'  

if DATE_COL in df.index.names:
    if DATE_COL in df.columns:
        
        df = df.reset_index(drop=True)
    else:
       
        df = df.reset_index()


if df.index.name == DATE_COL:
     df = df.reset_index(drop=True)
     

df = df.reset_index(drop=True)


df[DATE_COL] = pd.to_datetime(df[DATE_COL])
df = df.sort_values(DATE_COL)
df = df.reset_index(drop=True) 


y = df[TARGET_COL]

print(len(y))


df['day_of_week'] = df[DATE_COL].dt.dayofweek


df['month'] = df[DATE_COL].dt.month


df['day_of_month'] = df[DATE_COL].dt.day


df['is_weekend'] = (df['day_of_week'] >= 5).astype(float)

df['is_christmas_day'] = ((df[DATE_COL].dt.month == 12) & (df[DATE_COL].dt.day == 25)).astype(float)


promo_cols = [col for col in df.columns if col.startswith('promo_')]
print(f"Found {len(promo_cols)} promotion columns: {promo_cols}")

for col in promo_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(float)

EXOG_COLS = ['day_of_week', 'month', 'day_of_month', 'is_weekend', 'is_christmas_day'] + promo_cols
# Out:
# Loading data from ../dataset/subset_set.feather...
# 7610
# Found 16 promotion columns: ['promo_type_FRPG', 'promo_value_FRPG', 'promo_type_GAS', 'promo_value_GAS', 'promo_type_BOGO', 'promo_value_BOGO', 'promo_type_DISC', 'promo_value_DISC', 'promo_type_CIRC', 'promo_value_CIRC', 'promo_type_CIRE', 'promo_value_CIRE', 'promo_type_CLCP', 'promo_value_CLCP', 'promo_type_LFPE', 'promo_value_LFPE']

# %%
@dataclass
class TrainConfig:
    lookback: int = 30
    horizon: int = 153
    batch_size: int = 32
    train_size: int = 455
    val_size : int = 153
    lr: float = 1e-4
    epochs: int = 30
    weight_decay: float = 1e-3
    device: str = "cuda" if torch.cuda.is_available() else "cpu"

# %%
from dataclasses import dataclass
from typing import Tuple, Optional, List

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

def train_mlp_forecaster(
    df: pd.DataFrame, 
    cfg: TrainConfig,
    seed: int,
    loss_type: str,
    product_id: str,
    target_channel: int = 0,    
    val_ratio: float = 0.2,
    hidden_sizes=(16, 8),
    target_col: str = TARGET_COL,
    exog_cols: Optional[List[str]] = EXOG_COLS,
    test_size: Optional[int] = None,
):

    
    cols = [target_col] + (exog_cols if exog_cols else [])
    data = df[cols].values
    
    test_start_idx = -test_size if test_size is not None else -cfg.horizon
    val_end_idx = test_start_idx
    val_start_idx = val_end_idx - cfg.val_size
    train_end_idx = val_start_idx 
    
    train_data = data[:train_end_idx]
    

    scaler = RobustScaler()
    train_scaled = train_data.copy()
    train_target = train_data[:, target_channel:target_channel+1]
    train_scaled[:, target_channel:target_channel+1] = scaler.fit_transform(train_target)
    
    val_context_start_idx = val_start_idx
    val_context_data = data[val_context_start_idx : val_end_idx]
    
    val_scaled = val_context_data.copy()
    val_target = val_context_data[:, target_channel:target_channel+1]
    val_scaled[:, target_channel:target_channel+1] = scaler.transform(val_target)

    X_train, y_train_full = make_windows(train_scaled, cfg.lookback, cfg.horizon)
    X_val, y_val_full = make_windows(val_scaled, cfg.lookback, cfg.horizon)

    y_train = y_train_full[:, :, target_channel : target_channel + 1]
    y_val = y_val_full[:, :, target_channel : target_channel + 1]

    C_in = X_train.shape[2]
    
    print(f"Train/Val Split Indices:")
    print(f"  Train End: {train_end_idx}")
    print(f"  Val Range:     {val_start_idx} to {val_end_idx}")
    print(f"  Test Range:    {test_start_idx} to End")
    print(f"  Val Targets:   {y_val.shape[0]} windows created")
    print(f"Input Shape:  (Batch, {cfg.lookback}, {C_in})")
    print(f"Output Shape: (Batch, {cfg.horizon}, 1)")

    train_loader = DataLoader(WindowDataset(X_train, y_train), batch_size=cfg.batch_size, shuffle=True)
    val_loader = DataLoader(WindowDataset(X_val, y_val), batch_size=cfg.batch_size, shuffle=False)
        
    model = MLPForecaster(
        lookback=cfg.lookback,
        in_channels=C_in,
        horizon=cfg.horizon,
        out_dim=1, 
        hidden_sizes=hidden_sizes,
        dropout=0.2,
        activation="relu",
    ).to(cfg.device)

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
    
    if loss_type.lower() == 'mse':
        loss_fn = nn.MSELoss()
    elif loss_type.lower() == 'mae':
        loss_fn = nn.L1Loss()
    elif loss_type.lower() == 'huber':
        loss_fn = nn.HuberLoss()
    else:
        raise ValueError(f"Unsupported loss_type: {loss_type}. Choose 'mse', 'mae', or 'huber'.")

    best_val = float("inf")
    best_state = None
    
    train_losses = []
    val_losses = []

    model_dir = f'best_models/seed_{seed}/{loss_type}'
    os.makedirs(model_dir, exist_ok=True)
    best_model_path = f'{model_dir}/mlp_product_{product_id}.pth'
    best_epoch = 0
    for epoch in range(1, cfg.epochs + 1):
        model.train()
        train_loss = 0.0
        for xb, yb in train_loader:
            xb = xb.to(cfg.device)
            yb = yb.to(cfg.device)

            pred = model(xb)
            loss = loss_fn(pred, yb)

            opt.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()

            train_loss += loss.item() * xb.size(0)
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(cfg.device)
                yb = yb.to(cfg.device)
                pred = model(xb)
                val_loss += loss_fn(pred, yb).item() * xb.size(0)
                
        if len(val_loader.dataset) > 0:
            val_loss /= len(val_loader.dataset)
            val_losses.append(val_loss)
            
            if val_loss < best_val:
                best_val = val_loss
                best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
                torch.save(best_state, best_model_path)
                best_epoch = epoch
                print (f"Epoch {epoch}: Train Loss = {train_loss:.6f}, Val Loss = {val_loss:.6f} (New Best)")
        else:
            print("WARNING: Validation set is too small to form windows!")

    if hasattr(val_loader.dataset, "__len__") and len(val_loader.dataset) > 0:
        print(f"Best Val {loss_type.upper()}: {best_val:.6f} (Epoch {best_epoch})")
    if best_state is not None:
        model.load_state_dict(best_state)

    return model, scaler, train_losses, val_losses, best_epoch

# %%
def recursive_forecast(
    model: MLPForecaster,
    scaler: RobustScaler,
    recent_history: np.ndarray,  
    future_exog: np.ndarray,     
    target_channel: int = 0,
    device: Optional[str] = None,
) -> np.ndarray:
    """
    Recursively forecasts `horizon` steps using a 1-step-ahead model.
    Uses known `future_exog` for the next step's input.
    """
    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    
    horizon = len(future_exog)
    

    recent_history = np.asarray(recent_history, dtype=np.float32)
    if recent_history.ndim == 1:
        recent_history = recent_history[:, None]

    current_x_scaled = recent_history.copy()
    current_x_scaled[:, target_channel:target_channel+1] = scaler.transform(
        recent_history[:, target_channel:target_channel+1]
    )
    
    preds_scaled = []
    model = model.to(device).eval()

    input_window = current_x_scaled.copy()
    
    for i in range(horizon):

        x_tensor = torch.from_numpy(input_window).float().unsqueeze(0).to(device) # (1, L, C_in)
        y_pred = model(x_tensor)
        val_pred = y_pred.item()
        preds_scaled.append(val_pred)

        input_window = np.roll(input_window, -1, axis=0)
        
        input_window[-1, target_channel] = val_pred
        
        input_window[-1, 1:] = future_exog[i]
        
    preds_scaled = np.array(preds_scaled).reshape(-1, 1)
    
    preds = scaler.inverse_transform(preds_scaled).flatten()
    return preds

# %%
from model_utils.plots import plot_results
import os
import matplotlib.pyplot as plt

seeds = [42, 123, 999]
FEATURE_COLS = [TARGET_COL] + EXOG_COLS

# Create base output directory for plots
base_output_dir = "product_forecasts_recursive"
os.makedirs(base_output_dir, exist_ok=True)

# 1. Identify all products
# Check column name again just in case
id_col = 'item_id' if 'item_id' in df.columns else 'id' 
product_ids = df[id_col].unique()
print(f"Found {len(product_ids)} products: {product_ids}")

for product_id in product_ids:
    print(f"\n{'#'*40}")
    print(f"Processing Product ID: {product_id}")
    print(f"{'#'*40}")
    
    # Filter data for this product
    product_df = df[df[id_col] == product_id].copy()
    product_df = product_df.sort_values(DATE_COL).reset_index(drop=True)
        
    # -------------------------------------------------------------------------
    # Recursive Step-by-Step Forecasting (Iterative)
    # -------------------------------------------------------------------------
    print("\n>> Training Recursive Model (1-step ahead)...")
    cfg_recursive = TrainConfig(
            lookback=30,
            horizon=1,   # Train to predict 1 step
            batch_size=32,
            train_size=453,
            val_size=153, 
            lr=1e-4,
            epochs=1000, 
            weight_decay=1e-3,
        )    
    # Prepare data splits for plotting (Indices)
    # Based on TrainConfig: val_size=153, test_size=153
    test_size = 153
    val_size = 153
    
    # Slices
    test_slice = slice(-test_size, None)
    val_slice = slice(-(test_size + val_size), -test_size)
    train_slice = slice(None, -(test_size + val_size))
    
    # Dates
    train_index = product_df[DATE_COL].iloc[train_slice]
    val_index = product_df[DATE_COL].iloc[val_slice]
    test_index = product_df[DATE_COL].iloc[test_slice]
    
    # Values (Target)
    train_values = product_df[TARGET_COL].iloc[train_slice].values
    val_values = product_df[TARGET_COL].iloc[val_slice].values
    test_values = product_df[TARGET_COL].iloc[test_slice].values
    
    # Determine test start index for accessing exogenous variables
    test_start_idx = -test_size
    history_start_idx = test_start_idx - cfg_recursive.lookback # Assuming lookback 48
    
    # Get history for [Target, Exog...]
    recent_history_df = product_df[FEATURE_COLS].iloc[history_start_idx : test_start_idx]
    recent_history = recent_history_df.values

    for seed in seeds:
        print(f"\n{'='*20} SEED {seed} (Product {product_id}) {'='*20}")
        
        # Create seed-specific directory
        seed_dir = os.path.join(base_output_dir, f"seed_{seed}")
        os.makedirs(seed_dir, exist_ok=True)

        
        
        # Ensure Validation Size is sufficient for window creation
        # We need at least 1 window. N = L_v - lookback - horizon + 1.
        # If we want N >= 1, then L_v >= lookback + horizon.
        REQ_VAL_SIZE = cfg_recursive.lookback + cfg_recursive.horizon
        if cfg_recursive.val_size < REQ_VAL_SIZE:
             # Dynamically adjust to ensure code runs
             print(f"Adjusting val_size from {cfg_recursive.val_size} to {REQ_VAL_SIZE} to ensure 1 window.")
             cfg_recursive.val_size = REQ_VAL_SIZE
        
        torch.manual_seed(seed)
        np.random.seed(seed)
        
        model_recursive, scaler_recursive, train_loss_r, val_loss_r, best_epoch_r = train_mlp_forecaster(
            product_df, 
            cfg_recursive, 
            seed=seed,
            loss_type='mse',
            product_id=product_id,
            target_channel=0,
            hidden_sizes=(32,16),
            target_col=TARGET_COL,
            exog_cols=EXOG_COLS,
            test_size=153 
        )
        
        # Forecast Recursive
        # We need FUTURE Exogenous variables for the forecast horizon
        future_exog_df = product_df[EXOG_COLS].iloc[test_start_idx:]
        future_exog = future_exog_df.values
        
        if len(future_exog) != 153:
            future_exog = future_exog[:153]

        pred_recursive = recursive_forecast(
            model_recursive,
            scaler_recursive,
            recent_history, 
            future_exog,    
            target_channel=0
        )

        # -------------------------------------------------------------------------
        # Evaluation & Plotting
        # -------------------------------------------------------------------------
        
        # Recursive Metrics
        rmse_recursive = np.sqrt(mean_squared_error(test_values, pred_recursive))
        mae_recursive = mean_absolute_error(test_values, pred_recursive)
        
        print(f"\nResults for Product {product_id} - Seed {seed}:")
        print(f"Recursive: RMSE={rmse_recursive:.4f}, MAE={mae_recursive:.4f}")
        
    
        # Recursive Plot
        plot_results(
            train_values, val_values, test_values, pred_recursive,
            train_index, val_index, test_index,
            train_loss_r, val_loss_r,
            target_col=TARGET_COL,
            title=f'MLP Recursive Forecast (Prod {product_id}, Seed {seed}) - RMSE: {rmse_recursive:.2f} (Best Epoch: {best_epoch_r})',
            save_path=os.path.join(seed_dir, f"recursive_forecast_prod_{product_id}.png")
        )

        print(f"Saved plots to {seed_dir}")
# Out:
# Found 10 products: [ 26008 921558 213626 213625 213624 213628 213629 213630 213631 514230]
#
# ########################################
# Processing Product ID: 26008
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 26008) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.128277, Val Loss = 0.395512 (New Best)
# Epoch 2: Train Loss = 1.130670, Val Loss = 0.377153 (New Best)
# Epoch 3: Train Loss = 1.042119, Val Loss = 0.348692 (New Best)
# Epoch 9: Train Loss = 0.958412, Val Loss = 0.340868 (New Best)
# Epoch 10: Train Loss = 0.931072, Val Loss = 0.325606 (New Best)
# Epoch 14: Train Loss = 0.919809, Val Loss = 0.311009 (New Best)
# Epoch 18: Train Loss = 0.880306, Val Loss = 0.303073 (New Best)
# Epoch 19: Train Loss = 0.837522, Val Loss = 0.293263 (New Best)
# Epoch 20: Train Loss = 0.833243, Val Loss = 0.274026 (New Best)
# Epoch 23: Train Loss = 0.781949, Val Loss = 0.269420 (New Best)
# Epoch 24: Train Loss = 0.812301, Val Loss = 0.253352 (New Best)
# Epoch 27: Train Loss = 0.781524, Val Loss = 0.238536 (New Best)
# Epoch 28: Train Loss = 0.797952, Val Loss = 0.238409 (New Best)
# Epoch 30: Train Loss = 0.721861, Val Loss = 0.238371 (New Best)
# Epoch 32: Train Loss = 0.728401, Val Loss = 0.228528 (New Best)
# Epoch 35: Train Loss = 0.731062, Val Loss = 0.216094 (New Best)
# Epoch 36: Train Loss = 0.709297, Val Loss = 0.215175 (New Best)
# Epoch 39: Train Loss = 0.687231, Val Loss = 0.201294 (New Best)
# Epoch 46: Train Loss = 0.627664, Val Loss = 0.193097 (New Best)
# Epoch 49: Train Loss = 0.606821, Val Loss = 0.182718 (New Best)
# Epoch 58: Train Loss = 0.625777, Val Loss = 0.171319 (New Best)
# Epoch 61: Train Loss = 0.567995, Val Loss = 0.166090 (New Best)
# Epoch 67: Train Loss = 0.577823, Val Loss = 0.165534 (New Best)
# Epoch 73: Train Loss = 0.625577, Val Loss = 0.163771 (New Best)
# Epoch 76: Train Loss = 0.530248, Val Loss = 0.157527 (New Best)
# Best Val MSE: 0.157527 (Epoch 76)
#
# Results for Product 26008 - Seed 42:
# Recursive: RMSE=51.3382, MAE=27.9835
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 26008) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.276095, Val Loss = 0.350490 (New Best)
# Epoch 11: Train Loss = 0.985753, Val Loss = 0.349799 (New Best)
# Epoch 12: Train Loss = 0.933026, Val Loss = 0.330657 (New Best)
# Epoch 13: Train Loss = 0.934111, Val Loss = 0.330271 (New Best)
# Epoch 15: Train Loss = 0.916053, Val Loss = 0.309079 (New Best)
# Epoch 16: Train Loss = 0.913882, Val Loss = 0.308737 (New Best)
# Epoch 17: Train Loss = 0.829636, Val Loss = 0.302524 (New Best)
# Epoch 18: Train Loss = 0.852947, Val Loss = 0.297517 (New Best)
# Epoch 19: Train Loss = 0.878832, Val Loss = 0.290952 (New Best)
# Epoch 20: Train Loss = 0.832274, Val Loss = 0.259427 (New Best)
# Epoch 27: Train Loss = 0.778468, Val Loss = 0.244907 (New Best)
# Epoch 29: Train Loss = 0.763040, Val Loss = 0.237358 (New Best)
# Epoch 30: Train Loss = 0.782344, Val Loss = 0.236102 (New Best)
# Epoch 33: Train Loss = 0.764081, Val Loss = 0.225488 (New Best)
# Epoch 38: Train Loss = 0.723574, Val Loss = 0.219155 (New Best)
# Epoch 42: Train Loss = 0.682161, Val Loss = 0.208938 (New Best)
# Epoch 43: Train Loss = 0.696790, Val Loss = 0.200479 (New Best)
# Epoch 50: Train Loss = 0.691769, Val Loss = 0.192628 (New Best)
# Epoch 59: Train Loss = 0.607784, Val Loss = 0.178910 (New Best)
# Epoch 85: Train Loss = 0.535251, Val Loss = 0.173022 (New Best)
# Best Val MSE: 0.173022 (Epoch 85)
#
# Results for Product 26008 - Seed 123:
# Recursive: RMSE=52.4744, MAE=28.8889
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 26008) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.319100, Val Loss = 0.541252 (New Best)
# Epoch 2: Train Loss = 1.240696, Val Loss = 0.425144 (New Best)
# Epoch 4: Train Loss = 1.112745, Val Loss = 0.422306 (New Best)
# Epoch 5: Train Loss = 1.018526, Val Loss = 0.409079 (New Best)
# Epoch 7: Train Loss = 0.963887, Val Loss = 0.396468 (New Best)
# Epoch 8: Train Loss = 1.042665, Val Loss = 0.386307 (New Best)
# Epoch 9: Train Loss = 0.985393, Val Loss = 0.368557 (New Best)
# Epoch 10: Train Loss = 0.940737, Val Loss = 0.338562 (New Best)
# Epoch 11: Train Loss = 1.007061, Val Loss = 0.334360 (New Best)
# Epoch 14: Train Loss = 0.958021, Val Loss = 0.305453 (New Best)
# Epoch 19: Train Loss = 0.845789, Val Loss = 0.287942 (New Best)
# Epoch 21: Train Loss = 0.852841, Val Loss = 0.274593 (New Best)
# Epoch 25: Train Loss = 0.849897, Val Loss = 0.262764 (New Best)
# Epoch 26: Train Loss = 0.821460, Val Loss = 0.248425 (New Best)
# Epoch 34: Train Loss = 0.717456, Val Loss = 0.240364 (New Best)
# Epoch 37: Train Loss = 0.762346, Val Loss = 0.215705 (New Best)
# Epoch 41: Train Loss = 0.727873, Val Loss = 0.208896 (New Best)
# Epoch 50: Train Loss = 0.686860, Val Loss = 0.196637 (New Best)
# Epoch 55: Train Loss = 0.609861, Val Loss = 0.193154 (New Best)
# Epoch 62: Train Loss = 0.576624, Val Loss = 0.192643 (New Best)
# Epoch 63: Train Loss = 0.615561, Val Loss = 0.192021 (New Best)
# Epoch 69: Train Loss = 0.605361, Val Loss = 0.190160 (New Best)
# Epoch 72: Train Loss = 0.669267, Val Loss = 0.180105 (New Best)
# Epoch 91: Train Loss = 0.509822, Val Loss = 0.178137 (New Best)
# Best Val MSE: 0.178137 (Epoch 91)
#
# Results for Product 26008 - Seed 999:
# Recursive: RMSE=49.5983, MAE=27.1917
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 921558
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 921558) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.671529, Val Loss = 0.750359 (New Best)
# Epoch 2: Train Loss = 0.640068, Val Loss = 0.730552 (New Best)
# Epoch 3: Train Loss = 0.594113, Val Loss = 0.730427 (New Best)
# Epoch 10: Train Loss = 0.581685, Val Loss = 0.727879 (New Best)
# Epoch 12: Train Loss = 0.593926, Val Loss = 0.722202 (New Best)
# Epoch 17: Train Loss = 0.571205, Val Loss = 0.717573 (New Best)
# Epoch 20: Train Loss = 0.569320, Val Loss = 0.712196 (New Best)
# Epoch 30: Train Loss = 0.555119, Val Loss = 0.701942 (New Best)
# Epoch 60: Train Loss = 0.519724, Val Loss = 0.687185 (New Best)
# Best Val MSE: 0.687185 (Epoch 60)
#
# Results for Product 921558 - Seed 42:
# Recursive: RMSE=5.7969, MAE=4.5326
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 921558) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.781189, Val Loss = 0.823356 (New Best)
# Epoch 2: Train Loss = 0.646774, Val Loss = 0.737845 (New Best)
# Epoch 3: Train Loss = 0.665205, Val Loss = 0.717540 (New Best)
# Epoch 4: Train Loss = 0.624981, Val Loss = 0.710919 (New Best)
# Epoch 5: Train Loss = 0.626196, Val Loss = 0.702695 (New Best)
# Epoch 6: Train Loss = 0.609763, Val Loss = 0.684512 (New Best)
# Epoch 10: Train Loss = 0.595429, Val Loss = 0.679306 (New Best)
# Epoch 44: Train Loss = 0.548151, Val Loss = 0.674594 (New Best)
# Epoch 64: Train Loss = 0.519297, Val Loss = 0.671913 (New Best)
# Epoch 65: Train Loss = 0.515527, Val Loss = 0.661934 (New Best)
# Epoch 76: Train Loss = 0.506940, Val Loss = 0.652376 (New Best)
# Best Val MSE: 0.652376 (Epoch 76)
#
# Results for Product 921558 - Seed 123:
# Recursive: RMSE=5.8603, MAE=4.6606
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 921558) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.881648, Val Loss = 0.750029 (New Best)
# Epoch 2: Train Loss = 0.738819, Val Loss = 0.742841 (New Best)
# Epoch 3: Train Loss = 0.708254, Val Loss = 0.718739 (New Best)
# Epoch 45: Train Loss = 0.547461, Val Loss = 0.715903 (New Best)
# Epoch 65: Train Loss = 0.535102, Val Loss = 0.708547 (New Best)
# Epoch 74: Train Loss = 0.529335, Val Loss = 0.695961 (New Best)
# Epoch 97: Train Loss = 0.495894, Val Loss = 0.694262 (New Best)
# Best Val MSE: 0.694262 (Epoch 97)
#
# Results for Product 921558 - Seed 999:
# Recursive: RMSE=5.8322, MAE=4.5782
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213626
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213626) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.021569, Val Loss = 0.462185 (New Best)
# Epoch 2: Train Loss = 1.033712, Val Loss = 0.456457 (New Best)
# Epoch 3: Train Loss = 0.949163, Val Loss = 0.451414 (New Best)
# Epoch 4: Train Loss = 0.973261, Val Loss = 0.443419 (New Best)
# Epoch 5: Train Loss = 0.939112, Val Loss = 0.436384 (New Best)
# Epoch 6: Train Loss = 0.945922, Val Loss = 0.430024 (New Best)
# Epoch 7: Train Loss = 0.948291, Val Loss = 0.424804 (New Best)
# Epoch 8: Train Loss = 0.931789, Val Loss = 0.414229 (New Best)
# Epoch 9: Train Loss = 0.908341, Val Loss = 0.408182 (New Best)
# Epoch 10: Train Loss = 0.896282, Val Loss = 0.401704 (New Best)
# Epoch 11: Train Loss = 0.908345, Val Loss = 0.393460 (New Best)
# Epoch 12: Train Loss = 0.900554, Val Loss = 0.385724 (New Best)
# Epoch 13: Train Loss = 0.892354, Val Loss = 0.380825 (New Best)
# Epoch 14: Train Loss = 0.865231, Val Loss = 0.373533 (New Best)
# Epoch 15: Train Loss = 0.852230, Val Loss = 0.368961 (New Best)
# Epoch 16: Train Loss = 0.826033, Val Loss = 0.362875 (New Best)
# Epoch 17: Train Loss = 0.832103, Val Loss = 0.355495 (New Best)
# Epoch 18: Train Loss = 0.838486, Val Loss = 0.352393 (New Best)
# Epoch 19: Train Loss = 0.810941, Val Loss = 0.348691 (New Best)
# Epoch 20: Train Loss = 0.794278, Val Loss = 0.341908 (New Best)
# Epoch 21: Train Loss = 0.782390, Val Loss = 0.337879 (New Best)
# Epoch 22: Train Loss = 0.824042, Val Loss = 0.335922 (New Best)
# Epoch 23: Train Loss = 0.765877, Val Loss = 0.332211 (New Best)
# Epoch 24: Train Loss = 0.801087, Val Loss = 0.326863 (New Best)
# Epoch 25: Train Loss = 0.793064, Val Loss = 0.322040 (New Best)
# Epoch 26: Train Loss = 0.763131, Val Loss = 0.319093 (New Best)
# Epoch 28: Train Loss = 0.825463, Val Loss = 0.318904 (New Best)
# Epoch 29: Train Loss = 0.786359, Val Loss = 0.313176 (New Best)
# Epoch 30: Train Loss = 0.735433, Val Loss = 0.308964 (New Best)
# Epoch 31: Train Loss = 0.790382, Val Loss = 0.305738 (New Best)
# Epoch 32: Train Loss = 0.749347, Val Loss = 0.304497 (New Best)
# Epoch 33: Train Loss = 0.739137, Val Loss = 0.301996 (New Best)
# Epoch 34: Train Loss = 0.757796, Val Loss = 0.298992 (New Best)
# Epoch 35: Train Loss = 0.737133, Val Loss = 0.298865 (New Best)
# Epoch 36: Train Loss = 0.751042, Val Loss = 0.298707 (New Best)
# Epoch 38: Train Loss = 0.730107, Val Loss = 0.295801 (New Best)
# Epoch 39: Train Loss = 0.724674, Val Loss = 0.295733 (New Best)
# Epoch 40: Train Loss = 0.698999, Val Loss = 0.292712 (New Best)
# Epoch 41: Train Loss = 0.742748, Val Loss = 0.291021 (New Best)
# Epoch 44: Train Loss = 0.740623, Val Loss = 0.288627 (New Best)
# Epoch 45: Train Loss = 0.696454, Val Loss = 0.284487 (New Best)
# Epoch 47: Train Loss = 0.696181, Val Loss = 0.278428 (New Best)
# Epoch 49: Train Loss = 0.648399, Val Loss = 0.278297 (New Best)
# Epoch 50: Train Loss = 0.682059, Val Loss = 0.277494 (New Best)
# Epoch 56: Train Loss = 0.687443, Val Loss = 0.277371 (New Best)
# Epoch 57: Train Loss = 0.686953, Val Loss = 0.276251 (New Best)
# Epoch 61: Train Loss = 0.626617, Val Loss = 0.275623 (New Best)
# Epoch 62: Train Loss = 0.651971, Val Loss = 0.274964 (New Best)
# Epoch 64: Train Loss = 0.625759, Val Loss = 0.274851 (New Best)
# Epoch 65: Train Loss = 0.642949, Val Loss = 0.270965 (New Best)
# Epoch 68: Train Loss = 0.606237, Val Loss = 0.270359 (New Best)
# Epoch 74: Train Loss = 0.624044, Val Loss = 0.268904 (New Best)
# Epoch 75: Train Loss = 0.624891, Val Loss = 0.268120 (New Best)
# Epoch 78: Train Loss = 0.579177, Val Loss = 0.266539 (New Best)
# Epoch 98: Train Loss = 0.573978, Val Loss = 0.264571 (New Best)
# Best Val MSE: 0.264571 (Epoch 98)
#
# Results for Product 213626 - Seed 42:
# Recursive: RMSE=22.4186, MAE=14.9244
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213626) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.145962, Val Loss = 0.487068 (New Best)
# Epoch 2: Train Loss = 0.995784, Val Loss = 0.461578 (New Best)
# Epoch 3: Train Loss = 0.972640, Val Loss = 0.450516 (New Best)
# Epoch 4: Train Loss = 0.983972, Val Loss = 0.440715 (New Best)
# Epoch 5: Train Loss = 0.930568, Val Loss = 0.432853 (New Best)
# Epoch 6: Train Loss = 0.928205, Val Loss = 0.429937 (New Best)
# Epoch 7: Train Loss = 0.905867, Val Loss = 0.422629 (New Best)
# Epoch 8: Train Loss = 0.887376, Val Loss = 0.412942 (New Best)
# Epoch 9: Train Loss = 0.894311, Val Loss = 0.406145 (New Best)
# Epoch 10: Train Loss = 0.863456, Val Loss = 0.397925 (New Best)
# Epoch 11: Train Loss = 0.898149, Val Loss = 0.389353 (New Best)
# Epoch 12: Train Loss = 0.877293, Val Loss = 0.379579 (New Best)
# Epoch 13: Train Loss = 0.818576, Val Loss = 0.365075 (New Best)
# Epoch 14: Train Loss = 0.834354, Val Loss = 0.357564 (New Best)
# Epoch 15: Train Loss = 0.798133, Val Loss = 0.346807 (New Best)
# Epoch 16: Train Loss = 0.832608, Val Loss = 0.341618 (New Best)
# Epoch 17: Train Loss = 0.774673, Val Loss = 0.336304 (New Best)
# Epoch 19: Train Loss = 0.781561, Val Loss = 0.333811 (New Best)
# Epoch 20: Train Loss = 0.791502, Val Loss = 0.328909 (New Best)
# Epoch 22: Train Loss = 0.767779, Val Loss = 0.325931 (New Best)
# Epoch 23: Train Loss = 0.770500, Val Loss = 0.324095 (New Best)
# Epoch 24: Train Loss = 0.766298, Val Loss = 0.322623 (New Best)
# Epoch 25: Train Loss = 0.791389, Val Loss = 0.321070 (New Best)
# Epoch 26: Train Loss = 0.753265, Val Loss = 0.317617 (New Best)
# Epoch 27: Train Loss = 0.776737, Val Loss = 0.316178 (New Best)
# Epoch 28: Train Loss = 0.801077, Val Loss = 0.314118 (New Best)
# Epoch 29: Train Loss = 0.749592, Val Loss = 0.311025 (New Best)
# Epoch 30: Train Loss = 0.767728, Val Loss = 0.310746 (New Best)
# Epoch 31: Train Loss = 0.752185, Val Loss = 0.309016 (New Best)
# Epoch 32: Train Loss = 0.733910, Val Loss = 0.308033 (New Best)
# Epoch 33: Train Loss = 0.739523, Val Loss = 0.307061 (New Best)
# Epoch 35: Train Loss = 0.717576, Val Loss = 0.304519 (New Best)
# Epoch 36: Train Loss = 0.708281, Val Loss = 0.301029 (New Best)
# Epoch 37: Train Loss = 0.749643, Val Loss = 0.298437 (New Best)
# Epoch 38: Train Loss = 0.703850, Val Loss = 0.298002 (New Best)
# Epoch 39: Train Loss = 0.723939, Val Loss = 0.296794 (New Best)
# Epoch 40: Train Loss = 0.713930, Val Loss = 0.296323 (New Best)
# Epoch 41: Train Loss = 0.750052, Val Loss = 0.295130 (New Best)
# Epoch 44: Train Loss = 0.746645, Val Loss = 0.293503 (New Best)
# Epoch 45: Train Loss = 0.702563, Val Loss = 0.292001 (New Best)
# Epoch 46: Train Loss = 0.703370, Val Loss = 0.291625 (New Best)
# Epoch 48: Train Loss = 0.717399, Val Loss = 0.290213 (New Best)
# Epoch 49: Train Loss = 0.685122, Val Loss = 0.287748 (New Best)
# Epoch 50: Train Loss = 0.697017, Val Loss = 0.285924 (New Best)
# Epoch 51: Train Loss = 0.711874, Val Loss = 0.285200 (New Best)
# Epoch 54: Train Loss = 0.700707, Val Loss = 0.282781 (New Best)
# Epoch 55: Train Loss = 0.670462, Val Loss = 0.281932 (New Best)
# Epoch 67: Train Loss = 0.618996, Val Loss = 0.281892 (New Best)
# Epoch 75: Train Loss = 0.673771, Val Loss = 0.281134 (New Best)
# Epoch 76: Train Loss = 0.637719, Val Loss = 0.280398 (New Best)
# Best Val MSE: 0.280398 (Epoch 76)
#
# Results for Product 213626 - Seed 123:
# Recursive: RMSE=21.5880, MAE=14.2473
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213626) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.269587, Val Loss = 0.483768 (New Best)
# Epoch 2: Train Loss = 1.140629, Val Loss = 0.439252 (New Best)
# Epoch 3: Train Loss = 1.065750, Val Loss = 0.427318 (New Best)
# Epoch 4: Train Loss = 1.030011, Val Loss = 0.418703 (New Best)
# Epoch 5: Train Loss = 0.970290, Val Loss = 0.409440 (New Best)
# Epoch 6: Train Loss = 0.960124, Val Loss = 0.399001 (New Best)
# Epoch 7: Train Loss = 0.917971, Val Loss = 0.387992 (New Best)
# Epoch 8: Train Loss = 0.931276, Val Loss = 0.375455 (New Best)
# Epoch 9: Train Loss = 0.918098, Val Loss = 0.374217 (New Best)
# Epoch 10: Train Loss = 0.850472, Val Loss = 0.367928 (New Best)
# Epoch 11: Train Loss = 0.909991, Val Loss = 0.361960 (New Best)
# Epoch 12: Train Loss = 0.893811, Val Loss = 0.355521 (New Best)
# Epoch 13: Train Loss = 0.860872, Val Loss = 0.351461 (New Best)
# Epoch 14: Train Loss = 0.871954, Val Loss = 0.348893 (New Best)
# Epoch 15: Train Loss = 0.817739, Val Loss = 0.344813 (New Best)
# Epoch 16: Train Loss = 0.847431, Val Loss = 0.339742 (New Best)
# Epoch 18: Train Loss = 0.835071, Val Loss = 0.329412 (New Best)
# Epoch 19: Train Loss = 0.827259, Val Loss = 0.325838 (New Best)
# Epoch 20: Train Loss = 0.830217, Val Loss = 0.317726 (New Best)
# Epoch 22: Train Loss = 0.845613, Val Loss = 0.314962 (New Best)
# Epoch 23: Train Loss = 0.775154, Val Loss = 0.312489 (New Best)
# Epoch 24: Train Loss = 0.763668, Val Loss = 0.307525 (New Best)
# Epoch 25: Train Loss = 0.835286, Val Loss = 0.301381 (New Best)
# Epoch 26: Train Loss = 0.790559, Val Loss = 0.298573 (New Best)
# Epoch 27: Train Loss = 0.748675, Val Loss = 0.297265 (New Best)
# Epoch 28: Train Loss = 0.738099, Val Loss = 0.294305 (New Best)
# Epoch 29: Train Loss = 0.746719, Val Loss = 0.288217 (New Best)
# Epoch 31: Train Loss = 0.748590, Val Loss = 0.287299 (New Best)
# Epoch 32: Train Loss = 0.735345, Val Loss = 0.286225 (New Best)
# Epoch 33: Train Loss = 0.783698, Val Loss = 0.283524 (New Best)
# Epoch 45: Train Loss = 0.709715, Val Loss = 0.280431 (New Best)
# Epoch 46: Train Loss = 0.720832, Val Loss = 0.278874 (New Best)
# Epoch 47: Train Loss = 0.670600, Val Loss = 0.276981 (New Best)
# Epoch 54: Train Loss = 0.664357, Val Loss = 0.274165 (New Best)
# Epoch 73: Train Loss = 0.616979, Val Loss = 0.273869 (New Best)
# Epoch 74: Train Loss = 0.625362, Val Loss = 0.271215 (New Best)
# Epoch 75: Train Loss = 0.620725, Val Loss = 0.267400 (New Best)
# Epoch 76: Train Loss = 0.588084, Val Loss = 0.264911 (New Best)
# Best Val MSE: 0.264911 (Epoch 76)
#
# Results for Product 213626 - Seed 999:
# Recursive: RMSE=22.2499, MAE=14.7448
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213625
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213625) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.600623, Val Loss = 0.380925 (New Best)
# Epoch 2: Train Loss = 0.578748, Val Loss = 0.371679 (New Best)
# Epoch 3: Train Loss = 0.547211, Val Loss = 0.367260 (New Best)
# Epoch 4: Train Loss = 0.544251, Val Loss = 0.360360 (New Best)
# Epoch 5: Train Loss = 0.545847, Val Loss = 0.353521 (New Best)
# Epoch 6: Train Loss = 0.534193, Val Loss = 0.345266 (New Best)
# Epoch 7: Train Loss = 0.524366, Val Loss = 0.337065 (New Best)
# Epoch 8: Train Loss = 0.494144, Val Loss = 0.328345 (New Best)
# Epoch 9: Train Loss = 0.491551, Val Loss = 0.317843 (New Best)
# Epoch 10: Train Loss = 0.479954, Val Loss = 0.308256 (New Best)
# Epoch 11: Train Loss = 0.485269, Val Loss = 0.300412 (New Best)
# Epoch 12: Train Loss = 0.478990, Val Loss = 0.295795 (New Best)
# Epoch 13: Train Loss = 0.456496, Val Loss = 0.289152 (New Best)
# Epoch 14: Train Loss = 0.433574, Val Loss = 0.276326 (New Best)
# Epoch 15: Train Loss = 0.453071, Val Loss = 0.271486 (New Best)
# Epoch 16: Train Loss = 0.433172, Val Loss = 0.266225 (New Best)
# Epoch 17: Train Loss = 0.417834, Val Loss = 0.261836 (New Best)
# Epoch 18: Train Loss = 0.441413, Val Loss = 0.257324 (New Best)
# Epoch 19: Train Loss = 0.407286, Val Loss = 0.254343 (New Best)
# Epoch 20: Train Loss = 0.430075, Val Loss = 0.251236 (New Best)
# Epoch 21: Train Loss = 0.411714, Val Loss = 0.249739 (New Best)
# Epoch 22: Train Loss = 0.421246, Val Loss = 0.245326 (New Best)
# Epoch 23: Train Loss = 0.405618, Val Loss = 0.241743 (New Best)
# Epoch 25: Train Loss = 0.400144, Val Loss = 0.237536 (New Best)
# Epoch 29: Train Loss = 0.393816, Val Loss = 0.235005 (New Best)
# Epoch 30: Train Loss = 0.350959, Val Loss = 0.231357 (New Best)
# Epoch 33: Train Loss = 0.362613, Val Loss = 0.229045 (New Best)
# Epoch 34: Train Loss = 0.386308, Val Loss = 0.227516 (New Best)
# Epoch 36: Train Loss = 0.372971, Val Loss = 0.225814 (New Best)
# Epoch 37: Train Loss = 0.372923, Val Loss = 0.225012 (New Best)
# Epoch 39: Train Loss = 0.371263, Val Loss = 0.221987 (New Best)
# Epoch 44: Train Loss = 0.361226, Val Loss = 0.221376 (New Best)
# Epoch 45: Train Loss = 0.356325, Val Loss = 0.221100 (New Best)
# Epoch 48: Train Loss = 0.342121, Val Loss = 0.219028 (New Best)
# Epoch 54: Train Loss = 0.346726, Val Loss = 0.217436 (New Best)
# Epoch 57: Train Loss = 0.364679, Val Loss = 0.216772 (New Best)
# Epoch 58: Train Loss = 0.331688, Val Loss = 0.216227 (New Best)
# Epoch 60: Train Loss = 0.332692, Val Loss = 0.215652 (New Best)
# Epoch 61: Train Loss = 0.337760, Val Loss = 0.215310 (New Best)
# Epoch 64: Train Loss = 0.323841, Val Loss = 0.214381 (New Best)
# Epoch 76: Train Loss = 0.327159, Val Loss = 0.213208 (New Best)
# Epoch 77: Train Loss = 0.314035, Val Loss = 0.212533 (New Best)
# Best Val MSE: 0.212533 (Epoch 77)
#
# Results for Product 213625 - Seed 42:
# Recursive: RMSE=10.5460, MAE=7.8141
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213625) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.656066, Val Loss = 0.402957 (New Best)
# Epoch 2: Train Loss = 0.595323, Val Loss = 0.390600 (New Best)
# Epoch 3: Train Loss = 0.544459, Val Loss = 0.378639 (New Best)
# Epoch 4: Train Loss = 0.543348, Val Loss = 0.370799 (New Best)
# Epoch 5: Train Loss = 0.498783, Val Loss = 0.356554 (New Best)
# Epoch 6: Train Loss = 0.492793, Val Loss = 0.341364 (New Best)
# Epoch 7: Train Loss = 0.489870, Val Loss = 0.327247 (New Best)
# Epoch 8: Train Loss = 0.460717, Val Loss = 0.314969 (New Best)
# Epoch 9: Train Loss = 0.467434, Val Loss = 0.314347 (New Best)
# Epoch 10: Train Loss = 0.442835, Val Loss = 0.304098 (New Best)
# Epoch 11: Train Loss = 0.468901, Val Loss = 0.289667 (New Best)
# Epoch 13: Train Loss = 0.426943, Val Loss = 0.289417 (New Best)
# Epoch 14: Train Loss = 0.423047, Val Loss = 0.285324 (New Best)
# Epoch 15: Train Loss = 0.397666, Val Loss = 0.269465 (New Best)
# Epoch 17: Train Loss = 0.382533, Val Loss = 0.263627 (New Best)
# Epoch 18: Train Loss = 0.394765, Val Loss = 0.263298 (New Best)
# Epoch 21: Train Loss = 0.385186, Val Loss = 0.261165 (New Best)
# Epoch 22: Train Loss = 0.384678, Val Loss = 0.256021 (New Best)
# Epoch 23: Train Loss = 0.367164, Val Loss = 0.250055 (New Best)
# Epoch 28: Train Loss = 0.383178, Val Loss = 0.249028 (New Best)
# Epoch 29: Train Loss = 0.380979, Val Loss = 0.248003 (New Best)
# Epoch 31: Train Loss = 0.376034, Val Loss = 0.247735 (New Best)
# Epoch 32: Train Loss = 0.350825, Val Loss = 0.245202 (New Best)
# Epoch 33: Train Loss = 0.350866, Val Loss = 0.242500 (New Best)
# Epoch 35: Train Loss = 0.363490, Val Loss = 0.241424 (New Best)
# Epoch 37: Train Loss = 0.352552, Val Loss = 0.241185 (New Best)
# Epoch 40: Train Loss = 0.347723, Val Loss = 0.237168 (New Best)
# Epoch 41: Train Loss = 0.354485, Val Loss = 0.235375 (New Best)
# Epoch 52: Train Loss = 0.344440, Val Loss = 0.233740 (New Best)
# Epoch 53: Train Loss = 0.332815, Val Loss = 0.232964 (New Best)
# Epoch 54: Train Loss = 0.337892, Val Loss = 0.228374 (New Best)
# Epoch 86: Train Loss = 0.309176, Val Loss = 0.226065 (New Best)
# Best Val MSE: 0.226065 (Epoch 86)
#
# Results for Product 213625 - Seed 123:
# Recursive: RMSE=10.5388, MAE=7.8269
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213625) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.854329, Val Loss = 0.410332 (New Best)
# Epoch 2: Train Loss = 0.704958, Val Loss = 0.369648 (New Best)
# Epoch 3: Train Loss = 0.578937, Val Loss = 0.364622 (New Best)
# Epoch 4: Train Loss = 0.578169, Val Loss = 0.352280 (New Best)
# Epoch 5: Train Loss = 0.585396, Val Loss = 0.346792 (New Best)
# Epoch 7: Train Loss = 0.519912, Val Loss = 0.343934 (New Best)
# Epoch 8: Train Loss = 0.525762, Val Loss = 0.333823 (New Best)
# Epoch 9: Train Loss = 0.501167, Val Loss = 0.320334 (New Best)
# Epoch 10: Train Loss = 0.474577, Val Loss = 0.305726 (New Best)
# Epoch 11: Train Loss = 0.475835, Val Loss = 0.301015 (New Best)
# Epoch 12: Train Loss = 0.469032, Val Loss = 0.292505 (New Best)
# Epoch 13: Train Loss = 0.497257, Val Loss = 0.288037 (New Best)
# Epoch 14: Train Loss = 0.456265, Val Loss = 0.286768 (New Best)
# Epoch 15: Train Loss = 0.428346, Val Loss = 0.278199 (New Best)
# Epoch 16: Train Loss = 0.444692, Val Loss = 0.272299 (New Best)
# Epoch 18: Train Loss = 0.430200, Val Loss = 0.263679 (New Best)
# Epoch 19: Train Loss = 0.409579, Val Loss = 0.263665 (New Best)
# Epoch 20: Train Loss = 0.423993, Val Loss = 0.250345 (New Best)
# Epoch 21: Train Loss = 0.423536, Val Loss = 0.248123 (New Best)
# Epoch 23: Train Loss = 0.391047, Val Loss = 0.246693 (New Best)
# Epoch 25: Train Loss = 0.377271, Val Loss = 0.243315 (New Best)
# Epoch 26: Train Loss = 0.405027, Val Loss = 0.235440 (New Best)
# Epoch 27: Train Loss = 0.387427, Val Loss = 0.231400 (New Best)
# Epoch 32: Train Loss = 0.365012, Val Loss = 0.231057 (New Best)
# Epoch 33: Train Loss = 0.370832, Val Loss = 0.229957 (New Best)
# Epoch 34: Train Loss = 0.361183, Val Loss = 0.226507 (New Best)
# Epoch 37: Train Loss = 0.371752, Val Loss = 0.224848 (New Best)
# Epoch 39: Train Loss = 0.367477, Val Loss = 0.224672 (New Best)
# Epoch 40: Train Loss = 0.376851, Val Loss = 0.220908 (New Best)
# Epoch 42: Train Loss = 0.350961, Val Loss = 0.220261 (New Best)
# Epoch 51: Train Loss = 0.343097, Val Loss = 0.217687 (New Best)
# Epoch 61: Train Loss = 0.320507, Val Loss = 0.217194 (New Best)
# Epoch 63: Train Loss = 0.330276, Val Loss = 0.217043 (New Best)
# Epoch 68: Train Loss = 0.318794, Val Loss = 0.216611 (New Best)
# Epoch 70: Train Loss = 0.306187, Val Loss = 0.215831 (New Best)
# Epoch 74: Train Loss = 0.322265, Val Loss = 0.215803 (New Best)
# Epoch 79: Train Loss = 0.293670, Val Loss = 0.215766 (New Best)
# Epoch 83: Train Loss = 0.325793, Val Loss = 0.214520 (New Best)
# Epoch 84: Train Loss = 0.322277, Val Loss = 0.213888 (New Best)
# Epoch 87: Train Loss = 0.298495, Val Loss = 0.211962 (New Best)
# Best Val MSE: 0.211962 (Epoch 87)
#
# Results for Product 213625 - Seed 999:
# Recursive: RMSE=10.7029, MAE=7.9554
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213624
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213624) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.618974, Val Loss = 0.439364 (New Best)
# Epoch 2: Train Loss = 0.534649, Val Loss = 0.393012 (New Best)
# Epoch 3: Train Loss = 0.529395, Val Loss = 0.383118 (New Best)
# Epoch 7: Train Loss = 0.511166, Val Loss = 0.379022 (New Best)
# Epoch 8: Train Loss = 0.503509, Val Loss = 0.377789 (New Best)
# Epoch 9: Train Loss = 0.508651, Val Loss = 0.373848 (New Best)
# Epoch 10: Train Loss = 0.502262, Val Loss = 0.369102 (New Best)
# Epoch 11: Train Loss = 0.496919, Val Loss = 0.360503 (New Best)
# Epoch 16: Train Loss = 0.461321, Val Loss = 0.357506 (New Best)
# Epoch 17: Train Loss = 0.465850, Val Loss = 0.353100 (New Best)
# Epoch 18: Train Loss = 0.467542, Val Loss = 0.350413 (New Best)
# Epoch 20: Train Loss = 0.451307, Val Loss = 0.350336 (New Best)
# Epoch 21: Train Loss = 0.428209, Val Loss = 0.347363 (New Best)
# Epoch 22: Train Loss = 0.441898, Val Loss = 0.341168 (New Best)
# Epoch 23: Train Loss = 0.430944, Val Loss = 0.340670 (New Best)
# Epoch 24: Train Loss = 0.441301, Val Loss = 0.336742 (New Best)
# Epoch 26: Train Loss = 0.430451, Val Loss = 0.336550 (New Best)
# Epoch 27: Train Loss = 0.419973, Val Loss = 0.331178 (New Best)
# Epoch 32: Train Loss = 0.417475, Val Loss = 0.326720 (New Best)
# Epoch 33: Train Loss = 0.400736, Val Loss = 0.317780 (New Best)
# Epoch 34: Train Loss = 0.397913, Val Loss = 0.316326 (New Best)
# Epoch 37: Train Loss = 0.404331, Val Loss = 0.312891 (New Best)
# Epoch 39: Train Loss = 0.404308, Val Loss = 0.309883 (New Best)
# Epoch 43: Train Loss = 0.385578, Val Loss = 0.303055 (New Best)
# Epoch 51: Train Loss = 0.368810, Val Loss = 0.301687 (New Best)
# Epoch 55: Train Loss = 0.379227, Val Loss = 0.297062 (New Best)
# Epoch 66: Train Loss = 0.365592, Val Loss = 0.290669 (New Best)
# Best Val MSE: 0.290669 (Epoch 66)
#
# Results for Product 213624 - Seed 42:
# Recursive: RMSE=9.9137, MAE=7.5215
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213624) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.589833, Val Loss = 0.419299 (New Best)
# Epoch 3: Train Loss = 0.519051, Val Loss = 0.411225 (New Best)
# Epoch 4: Train Loss = 0.512508, Val Loss = 0.404095 (New Best)
# Epoch 5: Train Loss = 0.507107, Val Loss = 0.400203 (New Best)
# Epoch 9: Train Loss = 0.483882, Val Loss = 0.392714 (New Best)
# Epoch 11: Train Loss = 0.472590, Val Loss = 0.386302 (New Best)
# Epoch 12: Train Loss = 0.453447, Val Loss = 0.363648 (New Best)
# Epoch 13: Train Loss = 0.436137, Val Loss = 0.345795 (New Best)
# Epoch 15: Train Loss = 0.411824, Val Loss = 0.340765 (New Best)
# Epoch 24: Train Loss = 0.413203, Val Loss = 0.338002 (New Best)
# Epoch 26: Train Loss = 0.403475, Val Loss = 0.333096 (New Best)
# Epoch 29: Train Loss = 0.411557, Val Loss = 0.331360 (New Best)
# Epoch 42: Train Loss = 0.364115, Val Loss = 0.326589 (New Best)
# Epoch 46: Train Loss = 0.387179, Val Loss = 0.325704 (New Best)
# Epoch 51: Train Loss = 0.374892, Val Loss = 0.318020 (New Best)
# Best Val MSE: 0.318020 (Epoch 51)
#
# Results for Product 213624 - Seed 123:
# Recursive: RMSE=10.0711, MAE=7.7293
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213624) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.921602, Val Loss = 0.474516 (New Best)
# Epoch 2: Train Loss = 0.622076, Val Loss = 0.400353 (New Best)
# Epoch 6: Train Loss = 0.502463, Val Loss = 0.396171 (New Best)
# Epoch 7: Train Loss = 0.491616, Val Loss = 0.389776 (New Best)
# Epoch 8: Train Loss = 0.491669, Val Loss = 0.380503 (New Best)
# Epoch 9: Train Loss = 0.486728, Val Loss = 0.365202 (New Best)
# Epoch 13: Train Loss = 0.472797, Val Loss = 0.359949 (New Best)
# Epoch 14: Train Loss = 0.459423, Val Loss = 0.355422 (New Best)
# Epoch 15: Train Loss = 0.434021, Val Loss = 0.354553 (New Best)
# Epoch 16: Train Loss = 0.422770, Val Loss = 0.344362 (New Best)
# Epoch 18: Train Loss = 0.452876, Val Loss = 0.336071 (New Best)
# Epoch 22: Train Loss = 0.432987, Val Loss = 0.328837 (New Best)
# Epoch 31: Train Loss = 0.414968, Val Loss = 0.328556 (New Best)
# Epoch 33: Train Loss = 0.414840, Val Loss = 0.325294 (New Best)
# Epoch 34: Train Loss = 0.383865, Val Loss = 0.322614 (New Best)
# Epoch 36: Train Loss = 0.384886, Val Loss = 0.322470 (New Best)
# Epoch 41: Train Loss = 0.400403, Val Loss = 0.321395 (New Best)
# Epoch 42: Train Loss = 0.374783, Val Loss = 0.316704 (New Best)
# Epoch 43: Train Loss = 0.397083, Val Loss = 0.314599 (New Best)
# Epoch 61: Train Loss = 0.376471, Val Loss = 0.311553 (New Best)
# Best Val MSE: 0.311553 (Epoch 61)
#
# Results for Product 213624 - Seed 999:
# Recursive: RMSE=9.9924, MAE=7.6212
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213628
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213628) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.800146, Val Loss = 0.494674 (New Best)
# Epoch 2: Train Loss = 0.786539, Val Loss = 0.477892 (New Best)
# Epoch 3: Train Loss = 0.747967, Val Loss = 0.467028 (New Best)
# Epoch 4: Train Loss = 0.734132, Val Loss = 0.461635 (New Best)
# Epoch 5: Train Loss = 0.747562, Val Loss = 0.453605 (New Best)
# Epoch 6: Train Loss = 0.711203, Val Loss = 0.450704 (New Best)
# Epoch 7: Train Loss = 0.725396, Val Loss = 0.436373 (New Best)
# Epoch 8: Train Loss = 0.688699, Val Loss = 0.429027 (New Best)
# Epoch 9: Train Loss = 0.659807, Val Loss = 0.419625 (New Best)
# Epoch 10: Train Loss = 0.663048, Val Loss = 0.412085 (New Best)
# Epoch 11: Train Loss = 0.673546, Val Loss = 0.397275 (New Best)
# Epoch 12: Train Loss = 0.648824, Val Loss = 0.391669 (New Best)
# Epoch 13: Train Loss = 0.659447, Val Loss = 0.391064 (New Best)
# Epoch 14: Train Loss = 0.599408, Val Loss = 0.377641 (New Best)
# Epoch 16: Train Loss = 0.601662, Val Loss = 0.366180 (New Best)
# Epoch 17: Train Loss = 0.600887, Val Loss = 0.362909 (New Best)
# Epoch 18: Train Loss = 0.605763, Val Loss = 0.353344 (New Best)
# Epoch 19: Train Loss = 0.570312, Val Loss = 0.350865 (New Best)
# Epoch 20: Train Loss = 0.588089, Val Loss = 0.349824 (New Best)
# Epoch 22: Train Loss = 0.561620, Val Loss = 0.349014 (New Best)
# Epoch 23: Train Loss = 0.554740, Val Loss = 0.338519 (New Best)
# Epoch 30: Train Loss = 0.520541, Val Loss = 0.338244 (New Best)
# Epoch 31: Train Loss = 0.550018, Val Loss = 0.333213 (New Best)
# Epoch 36: Train Loss = 0.542812, Val Loss = 0.328783 (New Best)
# Epoch 46: Train Loss = 0.464124, Val Loss = 0.326094 (New Best)
# Epoch 48: Train Loss = 0.474170, Val Loss = 0.324277 (New Best)
# Epoch 66: Train Loss = 0.477397, Val Loss = 0.323785 (New Best)
# Epoch 67: Train Loss = 0.447937, Val Loss = 0.321767 (New Best)
# Epoch 76: Train Loss = 0.435123, Val Loss = 0.320869 (New Best)
# Epoch 79: Train Loss = 0.440540, Val Loss = 0.319920 (New Best)
# Epoch 88: Train Loss = 0.434478, Val Loss = 0.319498 (New Best)
# Best Val MSE: 0.319498 (Epoch 88)
#
# Results for Product 213628 - Seed 42:
# Recursive: RMSE=16.2247, MAE=12.0063
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213628) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.876417, Val Loss = 0.521716 (New Best)
# Epoch 2: Train Loss = 0.778534, Val Loss = 0.515672 (New Best)
# Epoch 3: Train Loss = 0.732985, Val Loss = 0.503721 (New Best)
# Epoch 4: Train Loss = 0.742103, Val Loss = 0.479238 (New Best)
# Epoch 5: Train Loss = 0.705463, Val Loss = 0.459750 (New Best)
# Epoch 6: Train Loss = 0.691574, Val Loss = 0.458935 (New Best)
# Epoch 7: Train Loss = 0.692011, Val Loss = 0.433139 (New Best)
# Epoch 8: Train Loss = 0.663477, Val Loss = 0.409984 (New Best)
# Epoch 10: Train Loss = 0.643086, Val Loss = 0.400341 (New Best)
# Epoch 15: Train Loss = 0.593192, Val Loss = 0.377023 (New Best)
# Epoch 20: Train Loss = 0.555372, Val Loss = 0.371882 (New Best)
# Epoch 23: Train Loss = 0.545414, Val Loss = 0.366243 (New Best)
# Epoch 25: Train Loss = 0.537280, Val Loss = 0.362158 (New Best)
# Epoch 29: Train Loss = 0.552023, Val Loss = 0.360867 (New Best)
# Epoch 32: Train Loss = 0.519970, Val Loss = 0.359222 (New Best)
# Epoch 33: Train Loss = 0.512180, Val Loss = 0.352725 (New Best)
# Best Val MSE: 0.352725 (Epoch 33)
#
# Results for Product 213628 - Seed 123:
# Recursive: RMSE=16.4923, MAE=12.5631
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213628) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 1.044852, Val Loss = 0.553209 (New Best)
# Epoch 2: Train Loss = 0.888959, Val Loss = 0.491249 (New Best)
# Epoch 3: Train Loss = 0.786337, Val Loss = 0.477418 (New Best)
# Epoch 4: Train Loss = 0.756565, Val Loss = 0.467081 (New Best)
# Epoch 5: Train Loss = 0.719512, Val Loss = 0.452348 (New Best)
# Epoch 6: Train Loss = 0.722892, Val Loss = 0.445918 (New Best)
# Epoch 8: Train Loss = 0.693319, Val Loss = 0.433472 (New Best)
# Epoch 9: Train Loss = 0.675444, Val Loss = 0.423705 (New Best)
# Epoch 10: Train Loss = 0.645471, Val Loss = 0.397201 (New Best)
# Epoch 11: Train Loss = 0.689090, Val Loss = 0.386057 (New Best)
# Epoch 14: Train Loss = 0.624274, Val Loss = 0.360517 (New Best)
# Epoch 18: Train Loss = 0.597568, Val Loss = 0.348662 (New Best)
# Epoch 19: Train Loss = 0.560977, Val Loss = 0.342176 (New Best)
# Epoch 20: Train Loss = 0.578403, Val Loss = 0.334321 (New Best)
# Epoch 26: Train Loss = 0.537428, Val Loss = 0.330792 (New Best)
# Epoch 33: Train Loss = 0.541813, Val Loss = 0.326902 (New Best)
# Epoch 34: Train Loss = 0.501083, Val Loss = 0.325234 (New Best)
# Epoch 41: Train Loss = 0.483578, Val Loss = 0.324950 (New Best)
# Epoch 42: Train Loss = 0.509699, Val Loss = 0.323563 (New Best)
# Epoch 49: Train Loss = 0.488681, Val Loss = 0.320774 (New Best)
# Epoch 53: Train Loss = 0.455367, Val Loss = 0.316061 (New Best)
# Best Val MSE: 0.316061 (Epoch 53)
#
# Results for Product 213628 - Seed 999:
# Recursive: RMSE=16.3253, MAE=11.9691
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213629
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213629) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.610996, Val Loss = 0.422856 (New Best)
# Epoch 2: Train Loss = 0.590811, Val Loss = 0.408023 (New Best)
# Epoch 3: Train Loss = 0.545363, Val Loss = 0.402212 (New Best)
# Epoch 4: Train Loss = 0.547849, Val Loss = 0.400059 (New Best)
# Epoch 5: Train Loss = 0.566299, Val Loss = 0.393898 (New Best)
# Epoch 6: Train Loss = 0.551775, Val Loss = 0.387930 (New Best)
# Epoch 7: Train Loss = 0.527813, Val Loss = 0.384233 (New Best)
# Epoch 8: Train Loss = 0.532377, Val Loss = 0.378032 (New Best)
# Epoch 9: Train Loss = 0.528246, Val Loss = 0.365400 (New Best)
# Epoch 10: Train Loss = 0.520961, Val Loss = 0.359238 (New Best)
# Epoch 11: Train Loss = 0.539173, Val Loss = 0.355822 (New Best)
# Epoch 14: Train Loss = 0.465853, Val Loss = 0.340745 (New Best)
# Epoch 15: Train Loss = 0.472378, Val Loss = 0.333011 (New Best)
# Epoch 16: Train Loss = 0.466005, Val Loss = 0.322723 (New Best)
# Epoch 17: Train Loss = 0.477824, Val Loss = 0.316142 (New Best)
# Epoch 18: Train Loss = 0.464569, Val Loss = 0.310082 (New Best)
# Epoch 19: Train Loss = 0.434786, Val Loss = 0.310059 (New Best)
# Epoch 21: Train Loss = 0.411791, Val Loss = 0.306805 (New Best)
# Epoch 22: Train Loss = 0.458129, Val Loss = 0.302740 (New Best)
# Epoch 23: Train Loss = 0.425005, Val Loss = 0.302120 (New Best)
# Epoch 25: Train Loss = 0.433127, Val Loss = 0.300326 (New Best)
# Epoch 26: Train Loss = 0.407646, Val Loss = 0.298644 (New Best)
# Epoch 28: Train Loss = 0.425441, Val Loss = 0.291563 (New Best)
# Epoch 30: Train Loss = 0.378667, Val Loss = 0.290417 (New Best)
# Epoch 31: Train Loss = 0.437117, Val Loss = 0.289292 (New Best)
# Epoch 32: Train Loss = 0.377664, Val Loss = 0.286947 (New Best)
# Epoch 35: Train Loss = 0.402631, Val Loss = 0.285467 (New Best)
# Epoch 41: Train Loss = 0.375831, Val Loss = 0.284923 (New Best)
# Epoch 42: Train Loss = 0.386823, Val Loss = 0.281782 (New Best)
# Epoch 43: Train Loss = 0.382584, Val Loss = 0.279887 (New Best)
# Epoch 45: Train Loss = 0.385879, Val Loss = 0.279858 (New Best)
# Epoch 46: Train Loss = 0.374790, Val Loss = 0.279812 (New Best)
# Epoch 47: Train Loss = 0.349379, Val Loss = 0.279724 (New Best)
# Epoch 52: Train Loss = 0.348926, Val Loss = 0.274761 (New Best)
# Epoch 76: Train Loss = 0.344866, Val Loss = 0.274452 (New Best)
# Epoch 77: Train Loss = 0.345203, Val Loss = 0.274309 (New Best)
# Epoch 79: Train Loss = 0.337618, Val Loss = 0.271317 (New Best)
# Epoch 89: Train Loss = 0.334124, Val Loss = 0.269839 (New Best)
# Epoch 90: Train Loss = 0.339732, Val Loss = 0.269284 (New Best)
# Epoch 92: Train Loss = 0.335740, Val Loss = 0.267442 (New Best)
# Best Val MSE: 0.267442 (Epoch 92)
#
# Results for Product 213629 - Seed 42:
# Recursive: RMSE=17.7775, MAE=13.3662
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213629) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.663146, Val Loss = 0.438001 (New Best)
# Epoch 2: Train Loss = 0.610667, Val Loss = 0.427631 (New Best)
# Epoch 3: Train Loss = 0.584393, Val Loss = 0.412027 (New Best)
# Epoch 4: Train Loss = 0.554007, Val Loss = 0.395268 (New Best)
# Epoch 5: Train Loss = 0.538762, Val Loss = 0.385331 (New Best)
# Epoch 7: Train Loss = 0.532513, Val Loss = 0.376600 (New Best)
# Epoch 8: Train Loss = 0.501847, Val Loss = 0.347163 (New Best)
# Epoch 9: Train Loss = 0.500392, Val Loss = 0.343144 (New Best)
# Epoch 11: Train Loss = 0.485207, Val Loss = 0.323282 (New Best)
# Epoch 12: Train Loss = 0.483984, Val Loss = 0.321104 (New Best)
# Epoch 13: Train Loss = 0.470719, Val Loss = 0.317508 (New Best)
# Epoch 15: Train Loss = 0.444540, Val Loss = 0.294275 (New Best)
# Epoch 16: Train Loss = 0.464836, Val Loss = 0.290411 (New Best)
# Epoch 22: Train Loss = 0.399451, Val Loss = 0.287751 (New Best)
# Epoch 23: Train Loss = 0.404388, Val Loss = 0.278233 (New Best)
# Epoch 29: Train Loss = 0.399129, Val Loss = 0.276368 (New Best)
# Epoch 37: Train Loss = 0.361009, Val Loss = 0.273478 (New Best)
# Epoch 38: Train Loss = 0.382866, Val Loss = 0.269898 (New Best)
# Epoch 40: Train Loss = 0.359035, Val Loss = 0.264449 (New Best)
# Epoch 70: Train Loss = 0.351000, Val Loss = 0.261245 (New Best)
# Best Val MSE: 0.261245 (Epoch 70)
#
# Results for Product 213629 - Seed 123:
# Recursive: RMSE=17.6878, MAE=13.1363
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213629) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.870272, Val Loss = 0.455058 (New Best)
# Epoch 2: Train Loss = 0.718523, Val Loss = 0.410888 (New Best)
# Epoch 3: Train Loss = 0.605980, Val Loss = 0.404885 (New Best)
# Epoch 4: Train Loss = 0.592038, Val Loss = 0.397174 (New Best)
# Epoch 5: Train Loss = 0.557696, Val Loss = 0.384055 (New Best)
# Epoch 6: Train Loss = 0.576484, Val Loss = 0.372326 (New Best)
# Epoch 7: Train Loss = 0.550837, Val Loss = 0.362570 (New Best)
# Epoch 8: Train Loss = 0.526883, Val Loss = 0.359962 (New Best)
# Epoch 10: Train Loss = 0.506566, Val Loss = 0.345566 (New Best)
# Epoch 11: Train Loss = 0.538587, Val Loss = 0.329966 (New Best)
# Epoch 13: Train Loss = 0.524594, Val Loss = 0.323197 (New Best)
# Epoch 14: Train Loss = 0.495853, Val Loss = 0.320447 (New Best)
# Epoch 16: Train Loss = 0.489706, Val Loss = 0.314905 (New Best)
# Epoch 17: Train Loss = 0.460119, Val Loss = 0.310911 (New Best)
# Epoch 18: Train Loss = 0.478464, Val Loss = 0.287662 (New Best)
# Epoch 23: Train Loss = 0.454091, Val Loss = 0.275066 (New Best)
# Epoch 26: Train Loss = 0.432721, Val Loss = 0.268562 (New Best)
# Epoch 38: Train Loss = 0.423442, Val Loss = 0.268143 (New Best)
# Epoch 41: Train Loss = 0.405410, Val Loss = 0.256267 (New Best)
# Epoch 51: Train Loss = 0.373731, Val Loss = 0.253564 (New Best)
# Epoch 58: Train Loss = 0.372060, Val Loss = 0.252146 (New Best)
# Epoch 59: Train Loss = 0.354014, Val Loss = 0.251732 (New Best)
# Epoch 60: Train Loss = 0.369056, Val Loss = 0.250349 (New Best)
# Epoch 68: Train Loss = 0.351202, Val Loss = 0.248672 (New Best)
# Epoch 77: Train Loss = 0.341901, Val Loss = 0.247007 (New Best)
# Best Val MSE: 0.247007 (Epoch 77)
#
# Results for Product 213629 - Seed 999:
# Recursive: RMSE=18.0545, MAE=13.3883
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213630
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213630) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.746736, Val Loss = 0.458945 (New Best)
# Epoch 2: Train Loss = 0.704199, Val Loss = 0.447106 (New Best)
# Epoch 3: Train Loss = 0.674447, Val Loss = 0.442732 (New Best)
# Epoch 4: Train Loss = 0.687807, Val Loss = 0.436612 (New Best)
# Epoch 5: Train Loss = 0.661200, Val Loss = 0.433602 (New Best)
# Epoch 6: Train Loss = 0.659413, Val Loss = 0.428105 (New Best)
# Epoch 7: Train Loss = 0.649856, Val Loss = 0.422023 (New Best)
# Epoch 8: Train Loss = 0.633510, Val Loss = 0.416025 (New Best)
# Epoch 9: Train Loss = 0.613819, Val Loss = 0.409151 (New Best)
# Epoch 10: Train Loss = 0.619046, Val Loss = 0.403627 (New Best)
# Epoch 11: Train Loss = 0.639522, Val Loss = 0.400399 (New Best)
# Epoch 12: Train Loss = 0.655163, Val Loss = 0.397207 (New Best)
# Epoch 13: Train Loss = 0.633049, Val Loss = 0.393671 (New Best)
# Epoch 14: Train Loss = 0.619133, Val Loss = 0.383032 (New Best)
# Epoch 15: Train Loss = 0.611433, Val Loss = 0.378491 (New Best)
# Epoch 16: Train Loss = 0.596727, Val Loss = 0.377565 (New Best)
# Epoch 17: Train Loss = 0.599224, Val Loss = 0.373501 (New Best)
# Epoch 18: Train Loss = 0.596451, Val Loss = 0.367720 (New Best)
# Epoch 19: Train Loss = 0.579570, Val Loss = 0.366012 (New Best)
# Epoch 20: Train Loss = 0.587116, Val Loss = 0.361813 (New Best)
# Epoch 21: Train Loss = 0.587346, Val Loss = 0.356655 (New Best)
# Epoch 22: Train Loss = 0.599088, Val Loss = 0.352855 (New Best)
# Epoch 26: Train Loss = 0.568521, Val Loss = 0.349219 (New Best)
# Epoch 27: Train Loss = 0.563944, Val Loss = 0.346516 (New Best)
# Epoch 28: Train Loss = 0.592812, Val Loss = 0.342815 (New Best)
# Epoch 32: Train Loss = 0.538846, Val Loss = 0.337939 (New Best)
# Epoch 33: Train Loss = 0.561803, Val Loss = 0.337448 (New Best)
# Epoch 34: Train Loss = 0.555947, Val Loss = 0.334343 (New Best)
# Epoch 35: Train Loss = 0.530322, Val Loss = 0.331851 (New Best)
# Epoch 38: Train Loss = 0.544159, Val Loss = 0.329070 (New Best)
# Epoch 40: Train Loss = 0.531540, Val Loss = 0.328175 (New Best)
# Epoch 41: Train Loss = 0.537232, Val Loss = 0.327753 (New Best)
# Epoch 42: Train Loss = 0.550693, Val Loss = 0.326031 (New Best)
# Epoch 43: Train Loss = 0.543493, Val Loss = 0.323855 (New Best)
# Epoch 44: Train Loss = 0.540238, Val Loss = 0.319833 (New Best)
# Epoch 50: Train Loss = 0.551529, Val Loss = 0.318940 (New Best)
# Epoch 52: Train Loss = 0.518773, Val Loss = 0.315570 (New Best)
# Epoch 53: Train Loss = 0.543093, Val Loss = 0.315255 (New Best)
# Epoch 54: Train Loss = 0.498244, Val Loss = 0.313075 (New Best)
# Epoch 55: Train Loss = 0.509387, Val Loss = 0.311605 (New Best)
# Epoch 56: Train Loss = 0.516799, Val Loss = 0.310745 (New Best)
# Epoch 65: Train Loss = 0.494781, Val Loss = 0.307912 (New Best)
# Epoch 66: Train Loss = 0.510903, Val Loss = 0.305957 (New Best)
# Epoch 74: Train Loss = 0.481617, Val Loss = 0.304029 (New Best)
# Epoch 82: Train Loss = 0.467869, Val Loss = 0.303733 (New Best)
# Epoch 96: Train Loss = 0.444870, Val Loss = 0.303417 (New Best)
# Best Val MSE: 0.303417 (Epoch 96)
#
# Results for Product 213630 - Seed 42:
# Recursive: RMSE=16.8191, MAE=12.4621
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213630) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.788323, Val Loss = 0.453603 (New Best)
# Epoch 2: Train Loss = 0.697182, Val Loss = 0.442361 (New Best)
# Epoch 3: Train Loss = 0.682299, Val Loss = 0.432591 (New Best)
# Epoch 4: Train Loss = 0.679656, Val Loss = 0.428422 (New Best)
# Epoch 5: Train Loss = 0.662048, Val Loss = 0.423220 (New Best)
# Epoch 7: Train Loss = 0.666001, Val Loss = 0.420480 (New Best)
# Epoch 8: Train Loss = 0.638031, Val Loss = 0.406941 (New Best)
# Epoch 9: Train Loss = 0.643241, Val Loss = 0.398645 (New Best)
# Epoch 10: Train Loss = 0.621039, Val Loss = 0.393198 (New Best)
# Epoch 11: Train Loss = 0.612507, Val Loss = 0.389475 (New Best)
# Epoch 12: Train Loss = 0.624366, Val Loss = 0.384387 (New Best)
# Epoch 13: Train Loss = 0.598524, Val Loss = 0.377323 (New Best)
# Epoch 15: Train Loss = 0.595529, Val Loss = 0.367044 (New Best)
# Epoch 16: Train Loss = 0.589093, Val Loss = 0.361403 (New Best)
# Epoch 17: Train Loss = 0.564354, Val Loss = 0.357626 (New Best)
# Epoch 19: Train Loss = 0.587320, Val Loss = 0.355076 (New Best)
# Epoch 20: Train Loss = 0.575748, Val Loss = 0.353351 (New Best)
# Epoch 22: Train Loss = 0.566522, Val Loss = 0.351288 (New Best)
# Epoch 23: Train Loss = 0.556817, Val Loss = 0.350920 (New Best)
# Epoch 26: Train Loss = 0.570551, Val Loss = 0.347826 (New Best)
# Epoch 27: Train Loss = 0.570027, Val Loss = 0.344135 (New Best)
# Epoch 28: Train Loss = 0.573645, Val Loss = 0.341554 (New Best)
# Epoch 32: Train Loss = 0.533904, Val Loss = 0.337445 (New Best)
# Epoch 36: Train Loss = 0.528393, Val Loss = 0.336627 (New Best)
# Epoch 37: Train Loss = 0.533015, Val Loss = 0.335839 (New Best)
# Epoch 38: Train Loss = 0.555543, Val Loss = 0.334161 (New Best)
# Epoch 40: Train Loss = 0.513673, Val Loss = 0.332402 (New Best)
# Epoch 41: Train Loss = 0.519542, Val Loss = 0.331493 (New Best)
# Epoch 42: Train Loss = 0.540505, Val Loss = 0.329292 (New Best)
# Epoch 46: Train Loss = 0.516392, Val Loss = 0.328562 (New Best)
# Epoch 48: Train Loss = 0.510360, Val Loss = 0.324046 (New Best)
# Epoch 53: Train Loss = 0.509167, Val Loss = 0.323326 (New Best)
# Epoch 54: Train Loss = 0.519993, Val Loss = 0.320719 (New Best)
# Epoch 58: Train Loss = 0.504463, Val Loss = 0.320621 (New Best)
# Epoch 59: Train Loss = 0.504721, Val Loss = 0.320297 (New Best)
# Epoch 64: Train Loss = 0.488950, Val Loss = 0.319129 (New Best)
# Epoch 65: Train Loss = 0.514890, Val Loss = 0.318239 (New Best)
# Epoch 82: Train Loss = 0.481159, Val Loss = 0.317703 (New Best)
# Epoch 93: Train Loss = 0.478843, Val Loss = 0.315043 (New Best)
# Best Val MSE: 0.315043 (Epoch 93)
#
# Results for Product 213630 - Seed 123:
# Recursive: RMSE=17.0173, MAE=12.5069
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213630) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.979829, Val Loss = 0.448797 (New Best)
# Epoch 2: Train Loss = 0.762835, Val Loss = 0.413565 (New Best)
# Epoch 3: Train Loss = 0.733285, Val Loss = 0.412592 (New Best)
# Epoch 4: Train Loss = 0.717807, Val Loss = 0.412431 (New Best)
# Epoch 6: Train Loss = 0.668497, Val Loss = 0.410215 (New Best)
# Epoch 7: Train Loss = 0.661183, Val Loss = 0.401686 (New Best)
# Epoch 8: Train Loss = 0.650411, Val Loss = 0.398545 (New Best)
# Epoch 9: Train Loss = 0.647019, Val Loss = 0.395220 (New Best)
# Epoch 10: Train Loss = 0.624034, Val Loss = 0.386364 (New Best)
# Epoch 11: Train Loss = 0.640518, Val Loss = 0.378785 (New Best)
# Epoch 12: Train Loss = 0.628069, Val Loss = 0.376514 (New Best)
# Epoch 13: Train Loss = 0.620261, Val Loss = 0.368573 (New Best)
# Epoch 14: Train Loss = 0.609834, Val Loss = 0.363483 (New Best)
# Epoch 15: Train Loss = 0.597346, Val Loss = 0.358535 (New Best)
# Epoch 16: Train Loss = 0.609466, Val Loss = 0.355826 (New Best)
# Epoch 17: Train Loss = 0.601543, Val Loss = 0.353683 (New Best)
# Epoch 18: Train Loss = 0.609722, Val Loss = 0.351427 (New Best)
# Epoch 19: Train Loss = 0.580768, Val Loss = 0.349010 (New Best)
# Epoch 20: Train Loss = 0.607407, Val Loss = 0.342259 (New Best)
# Epoch 21: Train Loss = 0.586034, Val Loss = 0.337110 (New Best)
# Epoch 22: Train Loss = 0.568838, Val Loss = 0.336538 (New Best)
# Epoch 23: Train Loss = 0.568291, Val Loss = 0.335258 (New Best)
# Epoch 25: Train Loss = 0.577606, Val Loss = 0.330004 (New Best)
# Epoch 26: Train Loss = 0.535856, Val Loss = 0.328868 (New Best)
# Epoch 27: Train Loss = 0.551847, Val Loss = 0.327904 (New Best)
# Epoch 29: Train Loss = 0.576626, Val Loss = 0.321834 (New Best)
# Epoch 30: Train Loss = 0.557349, Val Loss = 0.315226 (New Best)
# Epoch 31: Train Loss = 0.556790, Val Loss = 0.314558 (New Best)
# Epoch 32: Train Loss = 0.544987, Val Loss = 0.314537 (New Best)
# Epoch 33: Train Loss = 0.549628, Val Loss = 0.313292 (New Best)
# Epoch 35: Train Loss = 0.534747, Val Loss = 0.310183 (New Best)
# Epoch 36: Train Loss = 0.531697, Val Loss = 0.307693 (New Best)
# Epoch 39: Train Loss = 0.554416, Val Loss = 0.306674 (New Best)
# Epoch 42: Train Loss = 0.527033, Val Loss = 0.306206 (New Best)
# Epoch 43: Train Loss = 0.540485, Val Loss = 0.304434 (New Best)
# Epoch 51: Train Loss = 0.513356, Val Loss = 0.298920 (New Best)
# Epoch 75: Train Loss = 0.474145, Val Loss = 0.298215 (New Best)
# Epoch 76: Train Loss = 0.482518, Val Loss = 0.296120 (New Best)
# Best Val MSE: 0.296120 (Epoch 76)
#
# Results for Product 213630 - Seed 999:
# Recursive: RMSE=16.9423, MAE=12.2843
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 213631
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 213631) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.702782, Val Loss = 0.373615 (New Best)
# Epoch 2: Train Loss = 0.677524, Val Loss = 0.353086 (New Best)
# Epoch 3: Train Loss = 0.635019, Val Loss = 0.349529 (New Best)
# Epoch 4: Train Loss = 0.655488, Val Loss = 0.347982 (New Best)
# Epoch 5: Train Loss = 0.644460, Val Loss = 0.345919 (New Best)
# Epoch 7: Train Loss = 0.632766, Val Loss = 0.338430 (New Best)
# Epoch 8: Train Loss = 0.620947, Val Loss = 0.334589 (New Best)
# Epoch 9: Train Loss = 0.611360, Val Loss = 0.333020 (New Best)
# Epoch 10: Train Loss = 0.603383, Val Loss = 0.328583 (New Best)
# Epoch 11: Train Loss = 0.612359, Val Loss = 0.325877 (New Best)
# Epoch 13: Train Loss = 0.601030, Val Loss = 0.324796 (New Best)
# Epoch 14: Train Loss = 0.576346, Val Loss = 0.324031 (New Best)
# Epoch 16: Train Loss = 0.579700, Val Loss = 0.320449 (New Best)
# Epoch 17: Train Loss = 0.567127, Val Loss = 0.320411 (New Best)
# Epoch 18: Train Loss = 0.569009, Val Loss = 0.319385 (New Best)
# Epoch 20: Train Loss = 0.546052, Val Loss = 0.319297 (New Best)
# Epoch 22: Train Loss = 0.565724, Val Loss = 0.314087 (New Best)
# Epoch 25: Train Loss = 0.550454, Val Loss = 0.313720 (New Best)
# Best Val MSE: 0.313720 (Epoch 25)
#
# Results for Product 213631 - Seed 42:
# Recursive: RMSE=14.1564, MAE=10.7024
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 213631) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.743354, Val Loss = 0.365681 (New Best)
# Epoch 8: Train Loss = 0.605758, Val Loss = 0.365483 (New Best)
# Epoch 11: Train Loss = 0.592858, Val Loss = 0.364076 (New Best)
# Epoch 12: Train Loss = 0.590783, Val Loss = 0.361108 (New Best)
# Epoch 13: Train Loss = 0.590763, Val Loss = 0.357634 (New Best)
# Epoch 15: Train Loss = 0.582891, Val Loss = 0.353359 (New Best)
# Epoch 16: Train Loss = 0.565921, Val Loss = 0.351926 (New Best)
# Epoch 17: Train Loss = 0.572243, Val Loss = 0.349703 (New Best)
# Epoch 20: Train Loss = 0.572474, Val Loss = 0.346657 (New Best)
# Epoch 23: Train Loss = 0.551082, Val Loss = 0.346178 (New Best)
# Epoch 24: Train Loss = 0.560078, Val Loss = 0.339924 (New Best)
# Epoch 26: Train Loss = 0.545250, Val Loss = 0.335133 (New Best)
# Best Val MSE: 0.335133 (Epoch 26)
#
# Results for Product 213631 - Seed 123:
# Recursive: RMSE=14.2739, MAE=10.9401
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 213631) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.934879, Val Loss = 0.459502 (New Best)
# Epoch 2: Train Loss = 0.768161, Val Loss = 0.405263 (New Best)
# Epoch 3: Train Loss = 0.695632, Val Loss = 0.388234 (New Best)
# Epoch 4: Train Loss = 0.681863, Val Loss = 0.382711 (New Best)
# Epoch 5: Train Loss = 0.641677, Val Loss = 0.378592 (New Best)
# Epoch 8: Train Loss = 0.652565, Val Loss = 0.376034 (New Best)
# Epoch 9: Train Loss = 0.627525, Val Loss = 0.370537 (New Best)
# Epoch 10: Train Loss = 0.592516, Val Loss = 0.369586 (New Best)
# Epoch 11: Train Loss = 0.631162, Val Loss = 0.364106 (New Best)
# Epoch 14: Train Loss = 0.600528, Val Loss = 0.359124 (New Best)
# Epoch 15: Train Loss = 0.588764, Val Loss = 0.356713 (New Best)
# Epoch 22: Train Loss = 0.547738, Val Loss = 0.354937 (New Best)
# Epoch 26: Train Loss = 0.559692, Val Loss = 0.349718 (New Best)
# Best Val MSE: 0.349718 (Epoch 26)
#
# Results for Product 213631 - Seed 999:
# Recursive: RMSE=14.3600, MAE=10.8761
# Saved plots to product_forecasts_recursive\seed_999
#
# ########################################
# Processing Product ID: 514230
# ########################################
#
# >> Training Recursive Model (1-step ahead)...
#
# ==================== SEED 42 (Product 514230) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.535852, Val Loss = 0.379340 (New Best)
# Best Val MSE: 0.379340 (Epoch 1)
#
# Results for Product 514230 - Seed 42:
# Recursive: RMSE=5.1089, MAE=4.1063
# Saved plots to product_forecasts_recursive\seed_42
#
# ==================== SEED 123 (Product 514230) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.566223, Val Loss = 0.394842 (New Best)
# Epoch 2: Train Loss = 0.501804, Val Loss = 0.384525 (New Best)
# Epoch 5: Train Loss = 0.464397, Val Loss = 0.380855 (New Best)
# Epoch 6: Train Loss = 0.447304, Val Loss = 0.377092 (New Best)
# Epoch 7: Train Loss = 0.456715, Val Loss = 0.373875 (New Best)
# Epoch 8: Train Loss = 0.443009, Val Loss = 0.371608 (New Best)
# Epoch 9: Train Loss = 0.442155, Val Loss = 0.371274 (New Best)
# Epoch 19: Train Loss = 0.407557, Val Loss = 0.369745 (New Best)
# Best Val MSE: 0.369745 (Epoch 19)
#
# Results for Product 514230 - Seed 123:
# Recursive: RMSE=5.1897, MAE=4.1973
# Saved plots to product_forecasts_recursive\seed_123
#
# ==================== SEED 999 (Product 514230) ====================
# Train/Val Split Indices:
#   Train End: -306
#   Val Range:     -306 to -153
#   Test Range:    -153 to End
#   Val Targets:   123 windows created
# Input Shape:  (Batch, 30, 22)
# Output Shape: (Batch, 1, 1)
# Epoch 1: Train Loss = 0.776022, Val Loss = 0.411321 (New Best)
# Epoch 2: Train Loss = 0.573848, Val Loss = 0.385901 (New Best)
# Epoch 3: Train Loss = 0.552896, Val Loss = 0.377416 (New Best)
# Epoch 14: Train Loss = 0.412858, Val Loss = 0.374969 (New Best)
# Epoch 15: Train Loss = 0.425885, Val Loss = 0.374386 (New Best)
# Epoch 16: Train Loss = 0.409133, Val Loss = 0.373091 (New Best)
# Epoch 39: Train Loss = 0.371282, Val Loss = 0.367842 (New Best)
# Best Val MSE: 0.367842 (Epoch 39)
#
# Results for Product 514230 - Seed 999:
# Recursive: RMSE=5.6248, MAE=4.4181
# Saved plots to product_forecasts_recursive\seed_999
